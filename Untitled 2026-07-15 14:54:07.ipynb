# %%
select 1;
select 1;




print("hello world")

# %%
_results = []
_stream = sqlutils.sql_stream("select 1;\nselect 1;", connection_id="cd9usda5ycp6og", catalog_name="AwsDataCatalog")
for result in _stream:
    if result.status == "success":
        display(result.result)
        _results.append(result)
    else:
        # Save partial results for debugging before raising
        if len(_results) > 0:
            for r in _results:
                globals()[f'sql_output_4u64_{r.statement_index}'] = r.result
        raise Exception(result.error)

# All statements succeeded - save indexed vars if multiple results
if len(_results) > 1:
    for r in _results:
        globals()[f'sql_output_4u64_{r.statement_index}'] = r.result

# Always save main variable
sql_output_4u64 = _results[0].result if len(_results) == 1 else [r.result for r in _results]
